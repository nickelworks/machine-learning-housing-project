# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('./../../data/Ames_Housing_Price_Data.csv')

# %%
len(raw.columns)
# Out:
# 82

# %%
import matplotlib.pyplot as plt
import pandas as pd
from pandas.table.plotting import table # EDIT: see deprecation warnings below

ax = plt.subplot(111, frame_on=False) # no visible frame
ax.xaxis.set_visible(False)  # hide the x axis
ax.yaxis.set_visible(False)  # hide the y axis

table(ax, df)  # where df is your data frame

plt.savefig('mytable.png')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-29-b72b890a4520> in <module>
#       1 import matplotlib.pyplot as plt
#       2 import pandas as pd
# ----> 3 from pandas.table.plotting import table # EDIT: see deprecation warnings below
#       4
#       5 ax = plt.subplot(111, frame_on=False) # no visible frame
#
# ModuleNotFoundError: No module named 'pandas.table'

# %%
raw_null_count = raw[raw.columns[raw.isnull().any()]].isna().sum().to_frame()\
.reset_index().rename(columns = {'index':'Feature',0 : 'Null Count'})

# %%
import dataframe_image as image

# %%
image.export(raw_null_count,'raw_null_count.pdf')

# %%
raw_null_count[15:]
# Out:
#          Feature  Null Count
# 15  BsmtHalfBath           2
# 16   FireplaceQu        1241
# 17    GarageType         127
# 18   GarageYrBlt         129
# 19  GarageFinish         129
# 20    GarageCars           1
# 21    GarageArea           1
# 22    GarageQual         129
# 23    GarageCond         129
# 24        PoolQC        2571
# 25         Fence        2055
# 26   MiscFeature        2483

# %%
#Replace most N/A values with none and MasVnrType and Electrical with the mode.
categorical_list = ['Alley', 'BsmtQual', 'BsmtExposure', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish',
                    'PoolQC', 'Fence', 'MiscFeature', 'BsmtCond', 'BsmtFinType1', 'BsmtFinType2', 'GarageQual',
                    'GarageCond']

numerical_list = ['MasVnrArea', 'BsmtFullBath','BsmtHalfBath','BsmtFinSF1','BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
                  'GarageCars', 'GarageArea']

data['MasVnrType'].fillna(data['MasVnrType'].mode()[0], inplace = True)
data['Electrical'].fillna(data['Electrical'].mode()[0], inplace = True)

for el in categorical_list:
    data[el].fillna('None', inplace = True)

for el in numerical_list:
    data[el].fillna(0, inplace = True)


    
#402.88 is the ratio of LotArea/LotFrontage for all lot areas > 20,000 to fill in N/A values that did not have
#another value in their lotfrontage bucket.
# data_new['LotFrontage'].fillna(data_new['LotArea']/402.88, inplace = True)


#This one house had a garage type listed but all other garage features were NaN
data.at[data['PID'] == 910201180, 'GarageType'] = 'None'

# %%
cleaned_null_count = data[data.columns[data.isnull().any()]].isna().sum().to_frame()\
.reset_index().rename(columns = {'index':'Feature',0 : 'Null Count'})

# %%
cleaned_null_count
# Out:
#        Feature  Null Count
# 0  LotFrontage         462

# %%
data
# Out:
#       Unnamed: 0        PID  GrLivArea  SalePrice  MSSubClass MSZoning  \
# 0              1  909176150        856     126000          30       RL
# 1              2  905476230       1049     139500         120       RL
# 2              3  911128020       1001     124900          30  C (all)
# 3              4  535377150       1039     114000          70       RL
# 4              5  534177230       1665     227000          60       RL
# ...          ...        ...        ...        ...         ...      ...
# 2575         759  903205040        952     121000          30       RL
# 2576         760  905402060       1733     139600          20       RL
# 2577         761  909275030       2002     145000          90       RH
# 2578         762  907192040       1842     217500          60       RL
# 2579         763  906223180       1911     215000          60       RL
#
#       LotFrontage  LotArea Street Alley  ... ScreenPorch PoolArea PoolQC  \
# 0             NaN     7890   Pave  None  ...         166        0   None
# 1            42.0     4235   Pave  None  ...           0        0   None
# 2            60.0     6060   Pave  None  ...           0        0   None
# 3            80.0     8146   Pave  None  ...         111        0   None
# 4            70.0     8400   Pave  None  ...           0        0   None
# ...           ...      ...    ...   ...  ...         ...      ...    ...
# 2575          NaN     8854   Pave  None  ...          40        0   None
# 2576          NaN    13680   Pave  None  ...           0        0   None
# 2577         82.0     6270   Pave  None  ...           0        0   None
# 2578          NaN     8826   Pave  None  ...           0        0   None
# 2579         80.0     9554   Pave  None  ...           0        0   None
#
#      Fence MiscFeature MiscVal MoSold YrSold SaleType SaleCondition
# 0     None        None       0      3   2010      WD         Normal
# 1     None        None       0      2   2009      WD         Normal
# 2     None        None       0     11   2007      WD         Normal
# 3     None        None       0      5   2009      WD         Normal
# 4     None        None       0     11   2009      WD         Normal
# ...    ...         ...     ...    ...    ...      ...           ...
# 2575  None        None       0      5   2009      WD         Normal
# 2576  None        None       0      6   2009      WD         Normal
# 2577  None        None       0      8   2007      WD         Normal
# 2578  None        None       0      7   2007      WD         Normal
# 2579  None        None       0      9   2006      WD         Normal
#
# [2580 rows x 82 columns]

# %%
 prof = data[(data['Neighborhood'] == 'NoRidge') | (data['Neighborhood'] =='NridgeHt')]

# %%
data['Neighborhood'] in ['NoRidge','NridgeHt']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-35344931f681> in <module>
# ----> 1 data['Neighborhood'] in ['NoRidge','NridgeHt']
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1440     @final
#    1441     def __nonzero__(self):
# -> 1442         raise ValueError(
#    1443             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1444             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
pd.set_option('display.max_columns', None)
prof.sort_values(by = '1stFlrSF')
# Out:
#       Unnamed: 0        PID  GrLivArea  SalePrice  MSSubClass MSZoning  \
# 59            60  533135020       1755     235000          60       RL
# 936          937  528390210       1850     248000          60       RL
# 1495         496  528326060       2285     248000          60       RL
# 2237         421  533130020       1923     190000          60       RL
# 1810         811  528354100       2125     279500          60       RL
# ...          ...        ...        ...        ...         ...      ...
# 1926         110  528363110       2113     350000          20       RL
# 1686         687  533130170       2872     285000          50       RL
# 1007           8  528351010       4316     755000          60       RL
# 1727         728  528327060       2633     466500          20       RL
# 1316         317  528366050       3228     430000          20       RL
#
#       LotFrontage  LotArea Street Alley LotShape LandContour Utilities  \
# 59            NaN    11949   Pave  None      Reg         Lvl    AllPub
# 936           NaN    29959   Pave  None      IR2         Lvl    AllPub
# 1495          NaN    11000   Pave  None      Reg         Lvl    AllPub
# 2237        107.0    10186   Pave  None      IR1         Lvl    AllPub
# 1810         97.0    10990   Pave  None      IR1         Lvl    AllPub
# ...           ...      ...    ...   ...      ...         ...       ...
# 1926         91.0    10437   Pave  None      IR1         Lvl    AllPub
# 1686         85.0    10678   Pave  None      Reg         Lvl    AllPub
# 1007        104.0    21535   Pave  None      IR1         Lvl    AllPub
# 1727          NaN    11400   Pave  None      Reg         Lvl    AllPub
# 1316          NaN    12692   Pave  None      IR1         Lvl    AllPub
#
#      LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 59      Inside       Gtl      NoRidge       Norm       Norm     1Fam
# 936        FR2       Gtl      NoRidge       Norm       Norm     1Fam
# 1495       FR2       Gtl      NoRidge       Norm       Norm     1Fam
# 2237    Inside       Gtl      NoRidge       Norm       Norm     1Fam
# 1810   CulDSac       Gtl      NoRidge       Norm       Norm     1Fam
# ...        ...       ...          ...        ...        ...      ...
# 1926    Inside       Gtl      NoRidge       Norm       Norm     1Fam
# 1686    Inside       Gtl      NoRidge       Norm       Norm     1Fam
# 1007    Corner       Gtl      NoRidge       Norm       Norm     1Fam
# 1727    Inside       Gtl      NoRidge       Norm       Norm     1Fam
# 1316    Inside       Gtl      NoRidge       Norm       Norm     1Fam
#
#      HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 59       2Story            7            8       1991          2008     Gable
# 936      2Story            7            6       1994          1994     Gable
# 1495     2Story            8            5       2000          2000     Gable
# 2237     2Story            7            5       1992          1992     Gable
# 1810     2Story            7            5       1996          1997     Gable
# ...         ...          ...          ...        ...           ...       ...
# 1926     1Story            8            6       1995          1995       Hip
# 1686     1.5Fin            8            5       1992          2000       Hip
# 1007     2Story           10            6       1994          1995     Gable
# 1727     1Story           10            5       2001          2002       Hip
# 1316     1Story            8            5       1992          1993       Hip
#
#      RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual  \
# 59    CompShg     VinylSd     VinylSd    BrkFace       196.0        Gd
# 936   CompShg     HdBoard     HdBoard       None         0.0        Gd
# 1495  CompShg     VinylSd     VinylSd    BrkFace        72.0        Gd
# 2237  CompShg     HdBoard     HdBoard       None         0.0        Gd
# 1810  CompShg     VinylSd     VinylSd       None         0.0        Gd
# ...       ...         ...         ...        ...         ...       ...
# 1926  CompShg     MetalSd     MetalSd    BrkFace       660.0        Gd
# 1686  CompShg     HdBoard     HdBoard    BrkFace       337.0        Gd
# 1007  WdShngl     HdBoard     HdBoard    BrkFace      1170.0        Ex
# 1727  CompShg     VinylSd     VinylSd    BrkFace       705.0        Ex
# 1316  CompShg     BrkFace     BrkFace       None         0.0        Gd
#
#      ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 59          Gd      PConc       Gd       TA           No          GLQ
# 936         TA      PConc       Gd       TA           No          GLQ
# 1495        TA      PConc       Gd       TA           No          Unf
# 2237        TA      PConc       Gd       TA           No          GLQ
# 1810        TA      PConc       Ex       TA           No          GLQ
# ...        ...        ...      ...      ...          ...          ...
# 1926        Gd      PConc       Gd       TA           Gd          GLQ
# 1686        TA      PConc       Gd       TA           No          GLQ
# 1007        TA      PConc       Ex       TA           Gd          GLQ
# 1727        TA      PConc       Ex       TA           Gd          GLQ
# 1316        TA      PConc       Gd       TA           No          GLQ
#
#       BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating  \
# 59         601.0          ALQ       216.0      158.0        975.0    GasA
# 936        595.0          Unf         0.0      378.0        973.0    GasA
# 1495         0.0          Unf         0.0      969.0        969.0    GasA
# 2237       674.0          Unf         0.0       76.0        750.0    GasA
# 1810       851.0          Unf         0.0      213.0       1064.0    GasA
# ...          ...          ...         ...        ...          ...     ...
# 1926      1696.0          Unf         0.0      413.0       2109.0    GasA
# 1686       700.0          Unf         0.0      983.0       1683.0    GasA
# 1007      1455.0          Unf         0.0      989.0       2444.0    GasA
# 1727      1282.0          Unf         0.0     1351.0       2633.0    GasA
# 1316      1231.0          Unf         0.0     1969.0       3200.0    GasA
#
#      HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 59          Ex          Y      SBrkr       975       780             0
# 936         Ex          Y      SBrkr       979       871             0
# 1495        Ex          Y      SBrkr       997      1288             0
# 2237        Ex          Y      SBrkr      1061       862             0
# 1810        Ex          Y      SBrkr      1064      1061             0
# ...        ...        ...        ...       ...       ...           ...
# 1926        Ex          Y      SBrkr      2113         0             0
# 1686        Ex          Y      SBrkr      2129       743             0
# 1007        Ex          Y      SBrkr      2444      1872             0
# 1727        Ex          Y      SBrkr      2633         0             0
# 1316        Ex          Y      SBrkr      3228         0             0
#
#       BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 59             0.0           1.0         2         1             3
# 936            0.0           0.0         2         1             3
# 1495           0.0           0.0         2         1             4
# 2237           1.0           0.0         2         1             3
# 1810           1.0           0.0         2         1             4
# ...            ...           ...       ...       ...           ...
# 1926           1.0           0.0         2         1             2
# 1686           0.0           0.0         2         1             4
# 1007           0.0           1.0         3         1             4
# 1727           1.0           0.0         2         1             2
# 1316           1.0           0.0         3         0             4
#
#       KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces  \
# 59               1          Gd             7        Typ           1
# 936              1          Gd             7        Typ           1
# 1495             1          Gd             8        Typ           1
# 2237             1          Gd             8        Typ           1
# 1810             1          Gd            12        Typ           2
# ...            ...         ...           ...        ...         ...
# 1926             1          Gd             7        Typ           1
# 1686             1          Gd             9        Typ           1
# 1007             1          Ex            10        Typ           2
# 1727             1          Ex             8        Typ           2
# 1316             1          Gd            10        Typ           1
#
#      FireplaceQu GarageType GarageYrBlt GarageFinish  GarageCars  GarageArea  \
# 59            TA     Attchd      1991.0          Unf         2.0       524.0
# 936           Gd    BuiltIn      1994.0          Fin         2.0       467.0
# 1495          TA    BuiltIn      2000.0          Fin         3.0       648.0
# 2237          TA     Attchd      1992.0          RFn         2.0       564.0
# 1810          TA     Attchd      1996.0          RFn         2.0       576.0
# ...          ...        ...         ...          ...         ...         ...
# 1926          TA     Attchd      1995.0          Fin         3.0       839.0
# 1686          TA     Attchd      1992.0          Fin         2.0       541.0
# 1007          Ex     Attchd      1994.0          Fin         3.0       832.0
# 1727          Gd     Attchd      2001.0          RFn         3.0       804.0
# 1316          Gd     Attchd      1992.0          RFn         2.0       546.0
#
#      GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# 59           TA         TA          Y         502           60              0
# 936          TA         TA          Y         168           98              0
# 1495         TA         TA          Y           0           56              0
# 2237         TA         TA          Y         240           39              0
# 1810         TA         TA          Y         168            0              0
# ...         ...        ...        ...         ...          ...            ...
# 1926         TA         TA          Y         236           46              0
# 1686         TA         TA          Y           0           33              0
# 1007         TA         TA          Y         382           50              0
# 1727         TA         TA          Y         314          140              0
# 1316         TA         TA          Y         264           75            291
#
#       3SsnPorch  ScreenPorch  PoolArea PoolQC  Fence MiscFeature  MiscVal  \
# 59            0            0         0   None  GdPrv        None        0
# 936           0            0         0   None   None        None        0
# 1495          0            0         0   None   None        None        0
# 2237          0            0         0   None   None        None        0
# 1810          0            0         0   None   None        None        0
# ...         ...          ...       ...    ...    ...         ...      ...
# 1926          0            0         0   None   None        None        0
# 1686          0            0         0   None   None        None        0
# 1007          0            0         0   None   None        None        0
# 1727          0            0         0   None   None        None        0
# 1316          0            0         0   None   None        None        0
#
#       MoSold  YrSold SaleType SaleCondition
# 59         7    2009      WD         Normal
# 936        1    2009      WD         Normal
# 1495       6    2007      WD         Normal
# 2237       6    2010      WD         Normal
# 1810       6    2008      WD         Normal
# ...      ...     ...      ...           ...
# 1926       8    2008      WD         Normal
# 1686       4    2007      WD         Normal
# 1007       1    2007      WD         Normal
# 1727       3    2007      WD         Normal
# 1316       5    2007      WD         Normal
#
# [67 rows x 82 columns]

# %%
fuck = pd.read_csv('./../../charles/data/Ames_Real_Estate_Data.csv')
# Out:
# /Users/charlesphillips/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (36,40,81,87) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
len(fuck.columns)
# Out:
# 91

# %%
fuck.columns
# Out:
# Index(['MapRefNo', 'GeoRefNo', 'Tier', 'Range', 'Prop_Addr', 'ZngCdPr',
#        'ZngCdSc', 'ZngOLPr', 'ZngOLSc', 'ClassPr_S', 'ClassSc_S', 'Legal_Pr',
#        'SchD_S', 'TxD_S', 'MA_Ownr1', 'MA_Ownr2', 'MA_Line1', 'MA_Line2',
#        'MA_City', 'MA_State', 'MA_Zip1', 'MA_Zip2', 'Rcrd_Yr', 'Rcrd_Mo',
#        'Inst1_No', 'Inst1_Yr', 'Inst1_Mo', 'Inst1TPr', 'LndAc_S', 'ImpAc_S',
#        'OthAc_S', 'TtlVal_AsrYr', 'ValType', 'X1TPr_D', 'X1TSc_D', 'X2TPr_D',
#        'X2TSc_D', 'X1TPr_S', 'X1TSc_S', 'X2TPr_S', 'X2TSc_S', 'LndAcX1S',
#        'ImpAcX1S', 'ImpAcX2S', 'HSTtl_D', 'MilVal_D', 'HSTtl_S', 'MilVal_S',
#        'AcreX_S1', 'AcreGr', 'AcreNt_S', 'Neighborhood', 'LotArea', 'ParType',
#        'BldgNo_S', 'DwlgNo_S', 'BldgType', 'YrBuilt', 'HouseStyle',
#        'Foundation', 'RoofMatl', 'Ext1', 'Ext2', 'MasVnrType', 'Heating',
#        'Central Air', 'GLA', 'TtlBsmtSF', 'TotRmsAbvGrd', 'Fireplaces',
#        'PoolArea', 'GarageType', 'GarYrBlt', 'Cars', 'GarageArea',
#        'YrSold_YYYY', 'MoSold_MM', 'SalePrice', 'SaleType', 'SaleCond',
#        'ParclRel', 'PA-Nmbr', 'PA-PreD', 'PA-Strt', 'PA-StSfx', 'PA-PostD',
#        'PA-UnTyp', 'PA-UntNo', 'Date', 'Source', 'NmbrBRs'],
#       dtype='object')
