# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import Lasso
from sklearn.preprocessing import MinMaxScaler
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('../communal/Ames_Housing_Price_Data_cleaned_2.csv')

# %%
data.head()
predict = data.SalePrice
log_predict = np.log(predict)
data.drop('SalePrice', axis = 1, inplace = True)

data.drop(['PID', 'lot_bucket', 'mean_LotFrontage', 'Prop_Addr', 'GarageYrBlt', 'lat', 'long'], axis = 1, inplace = True)

data.drop(['YearRemodAdd', 'Exterior2nd', 'BsmtFinSF1', 'BsmtFinSF2',
           'BsmtUnfSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 
           'TotRmsAbvGrd', 'GarageCars'], axis = 1, inplace = True)
data['Total_Porch'] = data['OpenPorchSF'] + data['EnclosedPorch'] + \
                      data['3SsnPorch'] + data['ScreenPorch']
data.drop(['OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch'],
           axis = 1, inplace = True)

# %%
dummy = pd.get_dummies(data, drop_first = True)

# %%
from collections import defaultdict
num_iters = 10

params = {'alpha' : np.linspace(1e-5,1e-3,10)}
lasso = Lasso(max_iter = 200000)
gs = GridSearchCV(lasso,param_grid=params, verbose = 3, cv = 3, n_jobs = -1)

d = defaultdict(list)
trainR2 = []
testR2 = []
best_params = []

mins = []
maxs =[]

for i in range(num_iters):
    print(i, end = '/r')
    np.random.seed(i)
    
    X_train, X_test, y_train, y_test = train_test_split(dummy,log_predict,test_size = .3)
    scaler = MinMaxScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    
    mins.append(scaler.data_min_)
    maxs.append(scaler.data_max_)
    
    gs.fit(X_train ,y_train)
    best_estimator = gs.best_estimator_
    trainR2.append(best_estimator.score(X_train, y_train))
    testR2.append(best_estimator.score(X_test,y_test))
    best_params.append(gs.best_params_)
    
    
    important_features = pd.Series(best_estimator.coef_, 
                                  index = dummy.columns).sort_values(key = abs,ascending = False)

    
    for i, e in enumerate(important_features.index):
        d[e].append(i)
# Out:
# 0/rFitting 3 folds for each of 10 candidates, totalling 30 fits
# 1/rFitting 3 folds for each of 10 candidates, totalling 30 fits
# 2/rFitting 3 folds for each of 10 candidates, totalling 30 fits
# 3/rFitting 3 folds for each of 10 candidates, totalling 30 fits
# 4/rFitting 3 folds for each of 10 candidates, totalling 30 fits
# 5/rFitting 3 folds for each of 10 candidates, totalling 30 fits
# 6/rFitting 3 folds for each of 10 candidates, totalling 30 fits
# 7/rFitting 3 folds for each of 10 candidates, totalling 30 fits
# 8/rFitting 3 folds for each of 10 candidates, totalling 30 fits
# 9/rFitting 3 folds for each of 10 candidates, totalling 30 fits

# %%
top_f = ['GrLivArea', 'OverallQual', 'OverallCond','YearBuilt','TotalBsmtSF', 'GarageArea','Fireplaces',\
         'BsmtFullBath']

# %%
betas = []
for feature in dummy.columns:
    obs = dummy.iloc[244]
    play = obs.copy()
    play.at[feature] = play[feature] + 1
    play = scaler.transform([play])
    obs = scaler.transform([obs])
    beta = np.exp(best_estimator.predict(play))[0]- np.exp(best_estimator.predict(obs))[0]
    betas.append(beta)

    
    
np_betas = np.array(betas)
np_betas

all_betas = pd.Series(np_betas, index = dummy.columns).to_frame()

pd.set_option("display.max_rows", None)

all_betas
# Out:
#                                   0
# GrLivArea                 28.428935
# MSSubClass                 0.000000
# LotFrontage                8.581792
# LotArea                    0.000000
# OverallQual             6279.141136
# OverallCond             4832.893645
# YearBuilt                162.076026
# MasVnrArea                 0.000000
# TotalBsmtSF               13.155105
# BsmtFullBath            4227.779022
# BsmtHalfBath               0.000000
# FullBath                 808.159314
# HalfBath                 543.003095
# BedroomAbvGr               0.000000
# KitchenAbvGr               0.000000
# Fireplaces              1504.683790
# GarageArea                12.763801
# WoodDeckSF                 2.720111
# PoolArea                   0.000000
# MiscVal                    0.000000
# MoSold                   -66.321440
# YrSold                  -229.112632
# Total_Porch                5.486948
# MSZoning_C (all)      -11963.030414
# MSZoning_FV             2300.959437
# MSZoning_I (all)           0.000000
# MSZoning_RH                0.000000
# MSZoning_RL             6362.004166
# MSZoning_RM             -247.644704
# Street_Pave                0.000000
# Alley_None              -156.367753
# Alley_Pave                 0.000000
# LotShape_IR2            2498.537751
# LotShape_IR3               0.000000
# LotShape_Reg            -270.424990
# LandContour_HLS         1705.354146
# LandContour_Low          506.976766
# LandContour_Lvl          446.242912
# Utilities_NoSewr           0.000000
# LotConfig_CulDSac       2779.222805
# LotConfig_FR2          -1409.002160
# LotConfig_FR3              0.000000
# LotConfig_Inside          -5.358867
# LandSlope_Mod            221.928736
# LandSlope_Sev              0.000000
# Neighborhood_Blueste       0.000000
# Neighborhood_BrDale        0.000000
# Neighborhood_BrkSide     600.406049
# Neighborhood_ClearCr    3870.417601
# Neighborhood_CollgCr    -307.144847
# Neighborhood_Crawfor   12361.547551
# Neighborhood_Edwards   -4860.769040
# Neighborhood_Gilbert       0.000000
# Neighborhood_Greens        0.000000
# Neighborhood_GrnHill       0.000000
# Neighborhood_IDOTRR    -2509.720817
# Neighborhood_Landmrk       0.000000
# Neighborhood_MeadowV   -9676.918414
# Neighborhood_Mitchel       0.000000
# Neighborhood_NAmes     -2033.181153
# Neighborhood_NPkVill       0.000000
# Neighborhood_NWAmes        0.000000
# Neighborhood_NoRidge       0.000000
# Neighborhood_NridgHt    5532.741683
# Neighborhood_OldTown   -1400.832362
# Neighborhood_SWISU     -2918.742869
# Neighborhood_Sawyer        0.000000
# Neighborhood_SawyerW    -940.586796
# Neighborhood_Somerst    9390.976451
# Neighborhood_StoneBr    9027.713636
# Neighborhood_Timber      463.446886
# Neighborhood_Veenker       0.000000
# Condition1_Feedr           0.000000
# Condition1_Norm         4980.828701
# Condition1_PosA            0.000000
# Condition1_PosN            0.000000
# Condition1_RRAe            0.000000
# Condition1_RRAn            0.000000
# Condition1_RRNe            0.000000
# Condition1_RRNn            0.000000
# Condition2_Feedr           0.000000
# Condition2_Norm            0.000000
# Condition2_PosA            0.000000
# Condition2_PosN       -29167.771438
# Condition2_RRAe            0.000000
# Condition2_RRAn            0.000000
# Condition2_RRNn            0.000000
# BldgType_2fmCon            0.000000
# BldgType_Duplex        -6067.404664
# BldgType_Twnhs        -10096.478354
# BldgType_TwnhsE        -3782.034376
# HouseStyle_1.5Unf          0.000000
# HouseStyle_1Story       -718.288169
# HouseStyle_2.5Fin          0.000000
# HouseStyle_2.5Unf          0.000000
# HouseStyle_2Story       -517.385755
# HouseStyle_SFoyer          0.000000
# HouseStyle_SLvl            0.000000
# RoofStyle_Gable            0.000000
# RoofStyle_Gambrel          0.000000
# RoofStyle_Hip            433.088232
# RoofStyle_Mansard          0.000000
# RoofStyle_Shed             0.000000
# RoofMatl_Membran           0.000000
# RoofMatl_Metal             0.000000
# RoofMatl_Roll              0.000000
# RoofMatl_Tar&Grv        1129.163501
# RoofMatl_WdShake           0.000000
# RoofMatl_WdShngl           0.000000
# Exterior1st_AsphShn        0.000000
# Exterior1st_BrkComm        0.000000
# Exterior1st_BrkFace     5562.888735
# Exterior1st_CBlock         0.000000
# Exterior1st_CemntBd        0.000000
# Exterior1st_HdBoard      -74.950178
# Exterior1st_ImStucc        0.000000
# Exterior1st_MetalSd     1356.694568
# Exterior1st_Plywood        0.000000
# Exterior1st_PreCast        0.000000
# Exterior1st_Stucco         0.000000
# Exterior1st_VinylSd     1233.745539
# Exterior1st_Wd Sdng        0.000000
# Exterior1st_WdShing        0.000000
# MasVnrType_BrkFace         0.000000
# MasVnrType_None         -939.191123
# MasVnrType_Stone           0.000000
# ExterQual_Fa               0.000000
# ExterQual_Gd               0.000000
# ExterQual_TA           -1110.229635
# ExterCond_Fa           -7699.658682
# ExterCond_Gd               0.000000
# ExterCond_Po               0.000000
# ExterCond_TA             316.275180
# Foundation_CBlock          0.000000
# Foundation_PConc        2896.628708
# Foundation_Slab         -590.313595
# Foundation_Stone           0.000000
# Foundation_Wood            0.000000
# BsmtQual_Fa            -3256.554003
# BsmtQual_Gd            -1234.193841
# BsmtQual_None              0.000000
# BsmtQual_Po                0.000000
# BsmtQual_TA            -1811.769236
# BsmtCond_Fa            -1180.381949
# BsmtCond_Gd             1052.640661
# BsmtCond_None              0.000000
# BsmtCond_Po                0.000000
# BsmtCond_TA                0.000000
# BsmtExposure_Gd         6232.155765
# BsmtExposure_Mn        -1842.363191
# BsmtExposure_No        -2406.586212
# BsmtExposure_None          0.000000
# BsmtFinType1_BLQ           0.000000
# BsmtFinType1_GLQ        1234.701114
# BsmtFinType1_LwQ       -1849.852051
# BsmtFinType1_None          0.000000
# BsmtFinType1_Rec       -1991.692097
# BsmtFinType1_Unf       -3287.896246
# BsmtFinType2_BLQ       -1845.420806
# BsmtFinType2_GLQ           0.000000
# BsmtFinType2_LwQ        1049.017762
# BsmtFinType2_None          0.000000
# BsmtFinType2_Rec           0.000000
# BsmtFinType2_Unf           0.000000
# Heating_GasA               0.000000
# Heating_GasW            3897.669193
# Heating_Grav               0.000000
# Heating_OthW               0.000000
# Heating_Wall               0.000000
# HeatingQC_Fa           -1443.905270
# HeatingQC_Gd            -922.740916
# HeatingQC_Po               0.000000
# HeatingQC_TA           -2804.881564
# CentralAir_Y            7033.993516
# Electrical_FuseF           0.000000
# Electrical_FuseP           0.000000
# Electrical_SBrkr         297.132068
# KitchenQual_Fa         -7502.914308
# KitchenQual_Gd         -5075.324937
# KitchenQual_Po             0.000000
# KitchenQual_TA         -7144.435380
# Functional_Maj2        -3430.821107
# Functional_Min1            0.000000
# Functional_Min2            0.000000
# Functional_Mod             0.000000
# Functional_Sal             0.000000
# Functional_Typ          3410.007785
# FireplaceQu_Fa             0.000000
# FireplaceQu_Gd           563.694506
# FireplaceQu_None       -2318.600767
# FireplaceQu_Po             0.000000
# FireplaceQu_TA             0.000000
# GarageType_Attchd       2600.309598
# GarageType_Basment         0.000000
# GarageType_BuiltIn         0.000000
# GarageType_CarPort         0.000000
# GarageType_Detchd          0.000000
# GarageType_None            0.000000
# GarageFinish_None         -8.145346
# GarageFinish_RFn        -466.864455
# GarageFinish_Unf       -1178.335415
# GarageQual_Fa              0.000000
# GarageQual_Gd              0.000000
# GarageQual_None         -311.507849
# GarageQual_Po              0.000000
# GarageQual_TA              0.000000
# GarageCond_Fa          -2641.628000
# GarageCond_Gd              0.000000
# GarageCond_None           -0.138345
# GarageCond_Po              0.000000
# GarageCond_TA           2671.390685
# PavedDrive_P               0.000000
# PavedDrive_Y            3339.540008
# PoolQC_Fa                  0.000000
# PoolQC_Gd                  0.000000
# PoolQC_None                0.000000
# PoolQC_TA                  0.000000
# Fence_GdWo                 0.000000
# Fence_MnPrv                0.000000
# Fence_MnWw                 0.000000
# Fence_None               658.178047
# MiscFeature_None           0.000000
# MiscFeature_Othr           0.000000
# MiscFeature_Shed           0.000000
# MiscFeature_TenC           0.000000
# SaleType_CWD               0.000000
# SaleType_Con               0.000000
# SaleType_ConLD             0.000000
# SaleType_ConLI             0.000000
# SaleType_ConLw             0.000000
# SaleType_New               0.000000
# SaleType_Oth               0.000000
# SaleType_VWD               0.000000
# SaleType_WD                0.000000
# SaleCondition_AdjLand      0.000000
# SaleCondition_Alloca       0.000000
# SaleCondition_Family       0.000000
# SaleCondition_Normal    9704.434518
# SaleCondition_Partial  14184.332892

# %%
k = 10

for k in range(1000,1500):
    play = dummy.iloc[[k]][dummy.columns]
    print(i)
    print(f'predict : {np.dot(play,np_betas)[0] }')
    print(f'actual  : {predict[k]}\n\n')
# Out:
# 238
# predict : 25433.672333107912
# actual  : 172400
#
#
# 238
# predict : 40838.4107124834
# actual  : 224500
#
#
# 238
# predict : 17912.933474085992
# actual  : 157000
#
#
# 238
# predict : -6467.973467550124
# actual  : 140000
#
#
# 238
# predict : 27769.3464779972
# actual  : 183500
#
#
# 238
# predict : -48995.648850194935
# actual  : 80000
#
#
# 238
# predict : 34083.25271942059
# actual  : 175000
#
#
# 238
# predict : 23511.07875767909
# actual  : 181900
#
#
# 238
# predict : 75697.63987903995
# actual  : 315750
#
#
# 238
# predict : -2711.611676806642
# actual  : 145000
#
#
# 238
# predict : 39009.33212594745
# actual  : 197000
#
#
# 238
# predict : 879.0780758017208
# actual  : 84900
#
#
# 238
# predict : 6704.259925419057
# actual  : 158000
#
#
# 238
# predict : 14149.136255672609
# actual  : 156000
#
#
# 238
# predict : 73853.98282402381
# actual  : 305900
#
#
# 238
# predict : 64045.71667504712
# actual  : 257500
#
#
# 238
# predict : -17318.585288449132
# actual  : 116000
#
#
# 238
# predict : 657.2153580958256
# actual  : 143450
#
#
# 238
# predict : 72461.49034576281
# actual  : 277500
#
#
# 238
# predict : 35962.43198946648
# actual  : 200000
#
#
# 238
# predict : -12830.135097369726
# actual  : 105000
#
#
# 238
# predict : 180160.74281120155
# actual  : 755000
#
#
# 238
# predict : 55628.34508559102
# actual  : 204000
#
#
# 238
# predict : 58465.24512979912
# actual  : 255000
#
#
# 238
# predict : 21010.10951653082
# actual  : 156500
#
#
# 238
# predict : -47709.376560254954
# actual  : 86000
#
#
# 238
# predict : 59763.04114221729
# actual  : 240900
#
#
# 238
# predict : 90014.15101699461
# actual  : 268000
#
#
# 238
# predict : 47138.574112402915
# actual  : 244000
#
#
# 238
# predict : 17318.40832090535
# actual  : 155000
#
#
# 238
# predict : 1801.9373919220525
# actual  : 144500
#
#
# 238
# predict : -15803.225091400032
# actual  : 122500
#
#
# 238
# predict : 9011.708516991057
# actual  : 141000
#
#
# 238
# predict : -10022.750579637242
# actual  : 131000
#
#
# 238
# predict : 44623.16394923639
# actual  : 230000
#
#
# 238
# predict : 95406.37570069957
# actual  : 320000
#
#
# 238
# predict : 30448.37493069464
# actual  : 185900
#
#
# 238
# predict : -7676.04777817073
# actual  : 130000
#
#
# 238
# predict : 42843.65850078856
# actual  : 188000
#
#
# 238
# predict : -7241.314754327468
# actual  : 127500
#
#
# 238
# predict : 34191.426810228964
# actual  : 188500
#
#
# 238
# predict : 24417.598645272956
# actual  : 200100
#
#
# 238
# predict : 1860.8317773911986
# actual  : 148500
#
#
# 238
# predict : -13980.533672328223
# actual  : 137000
#
#
# 238
# predict : 16641.348327232292
# actual  : 157000
#
#
# 238
# predict : -34344.39549008472
# actual  : 82500
#
#
# 238
# predict : 6511.408589119033
# actual  : 168000
#
#
# 238
# predict : -29661.073548629764
# actual  : 108000
#
#
# 238
# predict : 14669.62610816647
# actual  : 177625
#
#
# 238
# predict : 56548.09323044983
# actual  : 235000
#
#
# 238
# predict : 20025.422237840772
# actual  : 155000
#
#
# 238
# predict : -23300.17223956465
# actual  : 108000
#
#
# 238
# predict : 19999.87187608506
# actual  : 155000
#
#
# 238
# predict : 23753.24554459972
# actual  : 175000
#
#
# 238
# predict : 71551.98293398035
# actual  : 362500
#
#
# 238
# predict : 27905.589295337035
# actual  : 184900
#
#
# 238
# predict : -13403.934523991134
# actual  : 135000
#
#
# 238
# predict : -10646.690861459356
# actual  : 150000
#
#
# 238
# predict : -10646.690861459356
# actual  : 150000
#
#
# 238
# predict : 34017.31787477073
# actual  : 195000
#
#
# 238
# predict : 40664.52075297665
# actual  : 210000
#
#
# 238
# predict : -10603.124393432925
# actual  : 133000
#
#
# 238
# predict : 81441.68275179458
# actual  : 286500
#
#
# 238
# predict : -13424.356477100984
# actual  : 119900
#
#
# 238
# predict : 13571.792112175666
# actual  : 190000
#
#
# 238
# predict : -7489.658123912173
# actual  : 137000
#
#
# 238
# predict : -20689.174247169693
# actual  : 115000
#
#
# 238
# predict : -27555.36611251277
# actual  : 113500
#
#
# 238
# predict : -2468.7745132294367
# actual  : 167500
#
#
# 238
# predict : 94534.48034655169
# actual  : 335000
#
#
# 238
# predict : -364.68119679251686
# actual  : 140000
#
#
# 238
# predict : 17860.827140344714
# actual  : 176000
#
#
# 238
# predict : -17392.53260986629
# actual  : 125000
#
#
# 238
# predict : -28030.482042658725
# actual  : 105000
#
#
# 238
# predict : -9671.227716928115
# actual  : 130250
#
#
# 238
# predict : 41724.07032205543
# actual  : 210900
#
#
# 238
# predict : -8782.630302092177
# actual  : 122000
#
#
# 238
# predict : 102172.14961543179
# actual  : 375000
#
#
# 238
# predict : 60138.6695700658
# actual  : 275000
#
#
# 238
# predict : -44377.85145279253
# actual  : 64500
#
#
# 238
# predict : -26169.807957706624
# actual  : 144000
#
#
# 238
# predict : 31630.112778034876
# actual  : 171500
#
#
# 238
# predict : -42390.18979475484
# actual  : 108500
#
#
# 238
# predict : 53375.38461972622
# actual  : 244400
#
#
# 238
# predict : 17985.970336007013
# actual  : 196000
#
#
# 238
# predict : -66309.33793955005
# actual  : 91000
#
#
# 238
# predict : 68138.80642034404
# actual  : 257000
#
#
# 238
# predict : 11046.406204759784
# actual  : 165000
#
#
# 238
# predict : -34427.83453751088
# actual  : 103000
#
#
# 238
# predict : -2492.9885733694537
# actual  : 143000
#
#
# 238
# predict : 72065.67565234582
# actual  : 286000
#
#
# 238
# predict : -168.73229101899778
# actual  : 126000
#
#
# 238
# predict : -2693.1570546441944
# actual  : 159950
#
#
# 238
# predict : -2693.1570546441944
# actual  : 159950
#
#
# 238
# predict : -10065.034406390041
# actual  : 140750
#
#
# 238
# predict : 67071.26858348807
# actual  : 270000
#
#
# 238
# predict : -24851.175805053557
# actual  : 118500
#
#
# 238
# predict : -20042.84097529872
# actual  : 110000
#
#
# 238
# predict : -12459.518948339624
# actual  : 123000
#
#
# 238
# predict : -30026.316290047194
# actual  : 119000
#
#
# 238
# predict : -11499.705139558355
# actual  : 126175
#
#
# 238
# predict : -1601.8257827287307
# actual  : 132000
#
#
# 238
# predict : -1601.8257827287307
# actual  : 132000
#
#
# 238
# predict : 2427.1957574748667
# actual  : 148000
#
#
# 238
# predict : -17015.34421961411
# actual  : 134500
#
#
# 238
# predict : -21118.6581046902
# actual  : 134432
#
#
# 238
# predict : 56795.88308921299
# actual  : 216837
#
#
# 238
# predict : 29187.600076342525
# actual  : 206900
#
#
# 238
# predict : -18828.241523909208
# actual  : 109900
#
#
# 238
# predict : -18828.241523909208
# actual  : 109900
#
#
# 238
# predict : -2321.502840594505
# actual  : 129000
#
#
# 238
# predict : -2466.0171242663637
# actual  : 133000
#
#
# 238
# predict : 58694.97123485
# actual  : 270000
#
#
# 238
# predict : -19915.14373496693
# actual  : 125000
#
#
# 238
# predict : 61235.60676701483
# actual  : 235500
#
#
# 238
# predict : -26282.93983066571
# actual  : 115000
#
#
# 238
# predict : -9762.078908947064
# actual  : 125000
#
#
# 238
# predict : 96854.2819340871
# actual  : 299800
#
#
# 238
# predict : -13794.502137619536
# actual  : 135000
#
#
# 238
# predict : -17123.96419836505
# actual  : 140000
#
#
# 238
# predict : -67395.28420657362
# actual  : 76000
#
#
# 238
# predict : 89792.61552613467
# actual  : 335000
#
#
# 238
# predict : -22730.596196966537
# actual  : 166000
#
#
# 238
# predict : -6887.76271168649
# actual  : 139500
#
#
# 238
# predict : 64295.50016324018
# actual  : 247900
#
#
# 238
# predict : 15620.305536529806
# actual  : 160000
#
#
# 238
# predict : 15347.175855146721
# actual  : 168000
#
#
# 238
# predict : 69027.79456491373
# actual  : 267000
#
#
# 238
# predict : -18572.263262843248
# actual  : 127500
#
#
# 238
# predict : 35888.82291631668
# actual  : 204750
#
#
# 238
# predict : 139296.49579666532
# actual  : 555000
#
#
# 238
# predict : 139296.49579666532
# actual  : 555000
#
#
# 238
# predict : 139296.49579666532
# actual  : 555000
#
#
# 238
# predict : 22370.41105771024
# actual  : 160000
#
#
# 238
# predict : 34609.66645384283
# actual  : 197000
#
#
# 238
# predict : 22080.485592447396
# actual  : 151400
#
#
# 238
# predict : -78064.95396329556
# actual  : 59000
#
#
# 238
# predict : 2560.310946978745
# actual  : 146000
#
#
# 238
# predict : 20193.60088558134
# actual  : 187500
#
#
# 238
# predict : 23268.57145303674
# actual  : 200000
#
#
# 238
# predict : -8997.67570222821
# actual  : 116500
#
#
# 238
# predict : 34938.44872594788
# actual  : 215000
#
#
# 238
# predict : 47348.654557301605
# actual  : 215000
#
#
# 238
# predict : 76740.4846471438
# actual  : 307000
#
#
# 238
# predict : 73791.49353364133
# actual  : 270000
#
#
# 238
# predict : 42619.0420402828
# actual  : 217000
#
#
# 238
# predict : -14467.045405674144
# actual  : 108500
#
#
# 238
# predict : -11866.942138500686
# actual  : 120000
#
#
# 238
# predict : -5197.3269193368615
# actual  : 141000
#
#
# 238
# predict : 63333.911575874314
# actual  : 253000
#
#
# 238
# predict : 11315.34623721888
# actual  : 174000
#
#
# 238
# predict : -15188.234385775751
# actual  : 110000
#
#
# 238
# predict : 17989.050735417695
# actual  : 180500
#
#
# 238
# predict : -992.5370095940889
# actual  : 140000
#
#
# 238
# predict : 65666.35088116123
# actual  : 262280
#
#
# 238
# predict : -5615.066688615421
# actual  : 128000
#
#
# 238
# predict : 47325.222103979904
# actual  : 202500
#
#
# 238
# predict : -29375.30867827742
# actual  : 114500
#
#
# 238
# predict : 32562.657835110324
# actual  : 200000
#
#
# 238
# predict : -17775.1551727131
# actual  : 124000
#
#
# 238
# predict : 18897.053753511107
# actual  : 175900
#
#
# 238
# predict : 45821.97259372444
# actual  : 231500
#
#
# 238
# predict : 49252.768411378784
# actual  : 217000
#
#
# 238
# predict : 2201.034345231252
# actual  : 159500
#
#
# 238
# predict : 113219.86043634237
# actual  : 462000
#
#
# 238
# predict : 4813.331463426992
# actual  : 154000
#
#
# 238
# predict : 100149.62306103826
# actual  : 403000
#
#
# 238
# predict : 20324.1099735967
# actual  : 190000
#
#
# 238
# predict : -41274.67528280849
# actual  : 85500
#
#
# 238
# predict : -3409.245232664922
# actual  : 140000
#
#
# 238
# predict : -4841.293908980908
# actual  : 160000
#
#
# 238
# predict : 76016.96264653292
# actual  : 266500
#
#
# 238
# predict : 103785.47331793059
# actual  : 315000
#
#
# 238
# predict : 51926.08315767383
# actual  : 221000
#
#
# 238
# predict : 79875.84007969458
# actual  : 300000
#
#
# 238
# predict : -30432.6026292296
# actual  : 103000
#
#
# 238
# predict : 13992.809093416668
# actual  : 166000
#
#
# 238
# predict : 7318.314351366484
# actual  : 145000
#
#
# 238
# predict : 1678.3734432527563
# actual  : 136900
#
#
# 238
# predict : 69291.13754764874
# actual  : 263550
#
#
# 238
# predict : -1240.2647771961638
# actual  : 140000
#
#
# 238
# predict : 42373.459004702745
# actual  : 205000
#
#
# 238
# predict : 84573.59202363144
# actual  : 295000
#
#
# 238
# predict : -4586.876358218666
# actual  : 153900
#
#
# 238
# predict : 15774.124951488397
# actual  : 158500
#
#
# 238
# predict : -10481.961762536666
# actual  : 130000
#
#
# 238
# predict : -38572.659835040686
# actual  : 96000
#
#
# 238
# predict : -25476.405343017308
# actual  : 122000
#
#
# 238
# predict : -25476.405343017308
# actual  : 122000
#
#
# 238
# predict : 83063.61667404219
# actual  : 316500
#
#
# 238
# predict : 27806.58006595407
# actual  : 197500
#
#
# 238
# predict : 43465.09585050796
# actual  : 210000
#
#
# 238
# predict : 31544.058766088157
# actual  : 219500
#
#
# 238
# predict : -13460.134431644343
# actual  : 133000
#
#
# 238
# predict : -51070.56172737497
# actual  : 79000
#
#
# 238
# predict : -129.3994471282349
# actual  : 126000
#
#
# 238
# predict : 8912.854177560832
# actual  : 155000
#
#
# 238
# predict : 17096.788884159934
# actual  : 162000
#
#
# 238
# predict : 33213.67382929451
# actual  : 188000
#
#
# 238
# predict : 100843.73691431322
# actual  : 402000
#
#
# 238
# predict : 19755.225539830048
# actual  : 228500
#
#
# 238
# predict : 14258.120728437207
# actual  : 170000
#
#
# 238
# predict : 23380.300581926887
# actual  : 180000
#
#
# 238
# predict : 11574.230442786298
# actual  : 161750
#
#
# 238
# predict : -32009.00089637167
# actual  : 97900
#
#
# 238
# predict : 48039.462522853515
# actual  : 212000
#
#
# 238
# predict : -19045.65420983685
# actual  : 122900
#
#
# 238
# predict : 82035.94712897373
# actual  : 348000
#
#
# 238
# predict : 9831.823915679357
# actual  : 172000
#
#
# 238
# predict : -11372.424453278421
# actual  : 128000
#
#
# 238
# predict : 45774.44173100474
# actual  : 227000
#
#
# 238
# predict : 18072.078631195473
# actual  : 160000
#
#
# 238
# predict : 16080.94109770999
# actual  : 170000
#
#
# 238
# predict : 20490.200019665936
# actual  : 158000
#
#
# 238
# predict : 22872.81385629764
# actual  : 167800
#
#
# 238
# predict : 22872.81385629764
# actual  : 167800
#
#
# 238
# predict : -5675.012462162878
# actual  : 134900
#
#
# 238
# predict : 33627.71075653972
# actual  : 190000
#
#
# 238
# predict : 18459.951107987144
# actual  : 192140
#
#
# 238
# predict : 2779.5527524570934
# actual  : 149300
#
#
# 238
# predict : -1157.079096508096
# actual  : 132000
#
#
# 238
# predict : 36773.834917538334
# actual  : 181000
#
#
# 238
# predict : 57043.93088609626
# actual  : 248500
#
#
# 238
# predict : 64900.55309964926
# actual  : 221500
#
#
# 238
# predict : 21013.474587445322
# actual  : 177000
#
#
# 238
# predict : 50540.25404264283
# actual  : 197000
#
#
# 238
# predict : -9872.511926879175
# actual  : 137000
#
#
# 238
# predict : 17445.71088439104
# actual  : 147500
#
#
# 238
# predict : -19880.006032459438
# actual  : 141500
#
#
# 238
# predict : 81291.63290847227
# actual  : 280000
#
#
# 238
# predict : 7664.749718118459
# actual  : 150000
#
#
# 238
# predict : 43839.18167146901
# actual  : 226700
#
#
# 238
# predict : -4379.100404760102
# actual  : 153000
#
#
# 238
# predict : 50655.367282234656
# actual  : 224000
#
#
# 238
# predict : 78241.9489976244
# actual  : 360000
#
#
# 238
# predict : 96056.43963534269
# actual  : 350000
#
#
# 238
# predict : -13847.241123637068
# actual  : 107500
#
#
# 238
# predict : 37285.25086986192
# actual  : 213000
#
#
# 238
# predict : 26609.500926762295
# actual  : 189500
#
#
# 238
# predict : 4520.595913014433
# actual  : 155000
#
#
# 238
# predict : 6399.309882992471
# actual  : 161500
#
#
# 238
# predict : 12115.85274583305
# actual  : 158000
#
#
# 238
# predict : 56694.841280020366
# actual  : 285000
#
#
# 238
# predict : 54713.16866227379
# actual  : 245350
#
#
# 238
# predict : 33327.02325828117
# actual  : 192000
#
#
# 238
# predict : 34759.28655753634
# actual  : 215000
#
#
# 238
# predict : 3163.9235003482318
# actual  : 139000
#
#
# 238
# predict : -6070.413219240203
# actual  : 117000
#
#
# 238
# predict : 4604.5016169265145
# actual  : 154000
#
#
# 238
# predict : -28327.604580798303
# actual  : 111000
#
#
# 238
# predict : -13205.762061768968
# actual  : 110000
#
#
# 238
# predict : 59512.58791634004
# actual  : 254900
#
#
# 238
# predict : -19265.88931067899
# actual  : 125000
#
#
# 238
# predict : 34104.24159238383
# actual  : 200000
#
#
# 238
# predict : 27642.620297062036
# actual  : 162900
#
#
# 238
# predict : -94688.81564082764
# actual  : 61000
#
#
# 238
# predict : 55182.45773423393
# actual  : 245000
#
#
# 238
# predict : 34643.774740541005
# actual  : 180000
#
#
# 238
# predict : 34643.774740541005
# actual  : 180000
#
#
# 238
# predict : -17428.21832111792
# actual  : 110000
#
#
# 238
# predict : -3446.3537331523257
# actual  : 140000
#
#
# 238
# predict : 2869.4142656267504
# actual  : 155000
#
#
# 238
# predict : 14547.590774974786
# actual  : 172900
#
#
# 238
# predict : 34336.37545855413
# actual  : 184000
#
#
# 238
# predict : 26930.7797709491
# actual  : 168675
#
#
# 238
# predict : 63144.489429193956
# actual  : 255900
#
#
# 238
# predict : 81104.7075725685
# actual  : 301000
#
#
# 238
# predict : 45245.82538301207
# actual  : 217000
#
#
# 238
# predict : -2925.107602907927
# actual  : 138500
#
#
# 238
# predict : -24216.883831664396
# actual  : 147000
#
#
# 238
# predict : 90221.79227417527
# actual  : 354000
#
#
# 238
# predict : 2040.3364397056866
# actual  : 135000
#
#
# 238
# predict : 16999.752187983075
# actual  : 160000
#
#
# 238
# predict : 637.9117199026514
# actual  : 127000
#
#
# 238
# predict : 39321.7054467767
# actual  : 219990
#
#
# 238
# predict : 46266.15118631959
# actual  : 235000
#
#
# 238
# predict : 101500.7475217763
# actual  : 377426
#
#
# 238
# predict : 22828.02213751967
# actual  : 160200
#
#
# 238
# predict : 72195.82050404995
# actual  : 306000
#
#
# 238
# predict : 26140.60336954909
# actual  : 190000
#
#
# 238
# predict : 42248.103702501394
# actual  : 214000
#
#
# 238
# predict : -9365.702407854318
# actual  : 134000
#
#
# 238
# predict : 32636.013405964826
# actual  : 170000
#
#
# 238
# predict : 31664.33574777306
# actual  : 190000
#
#
# 238
# predict : 34414.769991401874
# actual  : 179900
#
#
# 238
# predict : -6326.516596018511
# actual  : 112000
#
#
# 238
# predict : -8735.14738561504
# actual  : 140000
#
#
# 238
# predict : 49857.18271524814
# actual  : 233000
#
#
# 238
# predict : 16728.209524249774
# actual  : 176500
#
#
# 238
# predict : 26322.00978914555
# actual  : 200500
#
#
# 238
# predict : 22172.599288101424
# actual  : 235000
#
#
# 238
# predict : -6232.799568702816
# actual  : 140000
#
#
# 238
# predict : 37407.7999526927
# actual  : 191500
#
#
# 238
# predict : 27791.154021536873
# actual  : 190000
#
#
# 238
# predict : 69065.75410739292
# actual  : 302000
#
#
# 238
# predict : 13935.223046795873
# actual  : 158000
#
#
# 238
# predict : 21785.048723014537
# actual  : 187000
#
#
# 238
# predict : 7266.068505154282
# actual  : 149900
#
#
# 238
# predict : -18960.205702586216
# actual  : 119164
#
#
# 238
# predict : 15835.97966049955
# actual  : 143000
#
#
# 238
# predict : -12338.360477929178
# actual  : 138000
#
#
# 238
# predict : 35365.42434818775
# actual  : 170000
#
#
# 238
# predict : -34010.743453607196
# actual  : 100000
#
#
# 238
# predict : 10414.51967425883
# actual  : 154000
#
#
# 238
# predict : 51951.295953255845
# actual  : 239000
#
#
# 238
# predict : -53047.99994900543
# actual  : 90500
#
#
# 238
# predict : -4347.725637047552
# actual  : 135000
#
#
# 238
# predict : 8225.619113201683
# actual  : 155000
#
#
# 238
# predict : 47034.24978020694
# actual  : 221000
#
#
# 238
# predict : 63616.41249237198
# actual  : 230000
#
#
# 238
# predict : 9476.382958785922
# actual  : 144000
#
#
# 238
# predict : 37820.92152281373
# actual  : 207000
#
#
# 238
# predict : -21997.748645970423
# actual  : 129000
#
#
# 238
# predict : 35451.38575592532
# actual  : 197600
#
#
# 238
# predict : 68872.6000275379
# actual  : 280000
#
#
# 238
# predict : 43669.14845131943
# actual  : 203135
#
#
# 238
# predict : 20365.732581052696
# actual  : 162500
#
#
# 238
# predict : -29881.79783535708
# actual  : 98000
#
#
# 238
# predict : 54211.65100078599
# actual  : 235000
#
#
# 238
# predict : 9181.820950338733
# actual  : 157000
#
#
# 238
# predict : 7450.662712054851
# actual  : 143000
#
#
# 238
# predict : 12666.290506117744
# actual  : 150000
#
#
# 238
# predict : 46924.10434604884
# actual  : 225000
#
#
# 238
# predict : -2903.1678960362333
# actual  : 119750
#
#
# 238
# predict : 43369.570547579846
# actual  : 229000
#
#
# 238
# predict : 16514.069444699795
# actual  : 163000
#
#
# 238
# predict : 14397.759056125185
# actual  : 160000
#
#
# 238
# predict : 24895.434619018983
# actual  : 173500
#
#
# 238
# predict : -14664.333993210865
# actual  : 139000
#
#
# 238
# predict : 9873.802035085682
# actual  : 157000
#
#
# 238
# predict : 96994.05094122153
# actual  : 384500
#
#
# 238
# predict : 10265.702987619326
# actual  : 141000
#
#
# 238
# predict : -13313.222964499146
# actual  : 140000
#
#
# 238
# predict : 89653.28020483983
# actual  : 270000
#
#
# 238
# predict : 43469.302952921076
# actual  : 220000
#
#
# 238
# predict : 104017.85650280066
# actual  : 360000
#
#
# 238
# predict : 27048.571403112845
# actual  : 156000
#
#
# 238
# predict : 34469.333679107716
# actual  : 211000
#
#
# 238
# predict : -8562.446214239346
# actual  : 135500
#
#
# 238
# predict : 131026.79009391111
# actual  : 430000
#
#
# 238
# predict : 117738.3903771913
# actual  : 410000
#
#
# 238
# predict : -22625.478007133584
# actual  : 125000
#
#
# 238
# predict : 7407.090840811667
# actual  : 171500
#
#
# 238
# predict : 28218.915725213534
# actual  : 188000
#
#
# 238
# predict : 90010.98580285395
# actual  : 305000
#
#
# 238
# predict : -10027.744851492345
# actual  : 119000
#
#
# 238
# predict : 38663.583893474366
# actual  : 197900
#
#
# 238
# predict : 30006.974249548744
# actual  : 178000
#
#
# 238
# predict : 149402.24325715925
# actual  : 625000
#
#
# 238
# predict : -7532.422749651654
# actual  : 150000
#
#
# 238
# predict : 71279.14857304451
# actual  : 250000
#
#
# 238
# predict : 17793.436042271205
# actual  : 176000
#
#
# 238
# predict : 7821.540326670336
# actual  : 163000
#
#
# 238
# predict : 31730.614851203864
# actual  : 235000
#
#
# 238
# predict : 40158.18996742426
# actual  : 222000
#
#
# 238
# predict : 84797.5431355763
# actual  : 313000
#
#
# 238
# predict : 27219.33980476804
# actual  : 155000
#
#
# 238
# predict : -34451.67685026163
# actual  : 106000
#
#
# 238
# predict : 35418.564157292596
# actual  : 193000
#
#
# 238
# predict : -73473.05100996868
# actual  : 65000
#
#
# 238
# predict : -852.5483390041627
# actual  : 147000
#
#
# 238
# predict : 24052.794179544027
# actual  : 184000
#
#
# 238
# predict : -13936.670191520534
# actual  : 128250
#
#
# 238
# predict : -45423.093864456285
# actual  : 91000
#
#
# 238
# predict : -45423.093864456285
# actual  : 91000
#
#
# 238
# predict : -2518.0872561237193
# actual  : 140200
#
#
# 238
# predict : 3709.2782118091127
# actual  : 147000
#
#
# 238
# predict : -26562.029180953163
# actual  : 115000
#
#
# 238
# predict : 45853.24286664248
# actual  : 219500
#
#
# 238
# predict : 19593.727363937127
# actual  : 180000
#
#
# 238
# predict : 6556.913128924265
# actual  : 143000
#
#
# 238
# predict : 41578.18016845797
# actual  : 221000
#
#
# 238
# predict : -5852.170904399594
# actual  : 153500
#
#
# 238
# predict : -14583.264543792524
# actual  : 143000
#
#
# 238
# predict : 88801.57215913094
# actual  : 332000
#
#
# 238
# predict : 8420.436056933133
# actual  : 143000
#
#
# 238
# predict : 42934.318139769835
# actual  : 241000
#
#
# 238
# predict : -19423.736423628347
# actual  : 135750
#
#
# 238
# predict : -19615.4017493641
# actual  : 112500
#
#
# 238
# predict : 39136.53598936403
# actual  : 205950
#
#
# 238
# predict : 10730.222192322486
# actual  : 146000
#
#
# 238
# predict : 27141.79260948015
# actual  : 175000
#
#
# 238
# predict : 62648.849235219415
# actual  : 256000
#
#
# 238
# predict : -4080.307102972991
# actual  : 129000
#
#
# 238
# predict : -843.3343016012805
# actual  : 145000
#
#
# 238
# predict : 8599.12994888873
# actual  : 148800
#
#
# 238
# predict : -40620.04505630938
# actual  : 89500
#
#
# 238
# predict : 12234.049555634032
# actual  : 167000
#
#
# 238
# predict : 13053.019051646465
# actual  : 157900
#
#
# 238
# predict : 22492.93956509675
# actual  : 177500
#
#
# 238
# predict : 12474.218284478702
# actual  : 171500
#
#
# 238
# predict : -33109.65361877612
# actual  : 109900
#
#
# 238
# predict : 31530.576942430227
# actual  : 184000
#
#
# 238
# predict : 26589.51859081874
# actual  : 184500
#
#
# 238
# predict : 57486.63931613107
# actual  : 334000
#
#
# 238
# predict : 66842.33749504329
# actual  : 294000
#
#
# 238
# predict : 67320.95795784995
# actual  : 290000
#
#
# 238
# predict : -7444.663529047219
# actual  : 135000
#
#
# 238
# predict : 56578.40420517913
# actual  : 252000
#
#
# 238
# predict : 63199.00786260376
# actual  : 270000
#
#
# 238
# predict : 77772.18268670497
# actual  : 275000
#
#
# 238
# predict : 41139.02273178566
# actual  : 200000
#
#
# 238
# predict : 59016.67246511695
# actual  : 255900
#
#
# 238
# predict : 13850.754681411432
# actual  : 200000
#
#
# 238
# predict : 36438.631253182015
# actual  : 194500
#
#
# 238
# predict : 22452.69990607252
# actual  : 165500
#
#
# 238
# predict : 25301.125821861846
# actual  : 187500
#
#
# 238
# predict : 58274.03972074762
# actual  : 225000
#
#
# 238
# predict : -27816.052395946987
# actual  : 100000
#
#
# 238
# predict : 24702.166532292555
# actual  : 177000
#
#
# 238
# predict : 34237.62819978915
# actual  : 220000
#
#
# 238
# predict : 44006.116972168384
# actual  : 224900
#
#
# 238
# predict : 9722.849836333015
# actual  : 156500
#
#
# 238
# predict : -1735.0939811727148
# actual  : 139000
#
#
# 238
# predict : 3060.249813086237
# actual  : 153000
#
#
# 238
# predict : -50174.983424631006
# actual  : 88000
#
#
# 238
# predict : -18697.498766046832
# actual  : 115000
#
#
# 238
# predict : -42485.1179135493
# actual  : 100000
#
#
# 238
# predict : 3318.2987860383
# actual  : 195000
#
#
# 238
# predict : 21941.39767457405
# actual  : 172000
#
#
# 238
# predict : 76310.61124516244
# actual  : 259000
#
#
# 238
# predict : -29241.45947370131
# actual  : 90000
#
#
# 238
# predict : 44015.53513740428
# actual  : 202900
#
#
# 238
# predict : 46182.142748429906
# actual  : 206000
#
#
# 238
# predict : 65213.709955926286
# actual  : 222000
#
#
# 238
# predict : 29032.42242150585
# actual  : 172000
#
#
# 238
# predict : -6797.898873971077
# actual  : 138887
#
#
# 238
# predict : 2092.209693238139
# actual  : 139000
#
#
# 238
# predict : 56187.056124912924
# actual  : 278000
#
#
# 238
# predict : 63977.001587036124
# actual  : 249000
#
#
# 238
# predict : -2476.9984866774175
# actual  : 136500
#
#
# 238
# predict : -96335.11671306391
# actual  : 64500
#
#
# 238
# predict : 21990.491911142017
# actual  : 150000
#
#
# 238
# predict : 34410.965823550534
# actual  : 225000
#
#
# 238
# predict : -46228.24783405219
# actual  : 93900
#
#
# 238
# predict : 19074.87410293205
# actual  : 130000
#
#
# 238
# predict : 36856.07905241329
# actual  : 230000
#
#
# 238
# predict : -5812.152478418953
# actual  : 124000
#
#
# 238
# predict : 4502.367463667935
# actual  : 145900
#
#
# 238
# predict : -19765.100957823975
# actual  : 115000
#
#
# 238
# predict : 55911.98016762349
# actual  : 239500
#
#
# 238
# predict : 21594.51753956772
# actual  : 181000
#
#
# 238
# predict : 4555.688891656697
# actual  : 175000
#
#
# 238
# predict : -14982.121118048439
# actual  : 149500
#
#
# 238
# predict : 66844.3775636222
# actual  : 270000
#
#
# 238
# predict : 5871.262959606363
# actual  : 145000
#
#
# 238
# predict : 42643.18683057063
# actual  : 241500
#
#
# 238
# predict : -19664.01491283084
# actual  : 112500
#
#
# 238
# predict : -14375.352737696376
# actual  : 152000
#
#
# 238
# predict : 33394.0479292642
# actual  : 186500
#
#
# 238
# predict : 15479.113325148646
# actual  : 185000
#
#
# 238
# predict : 70382.50869886432
# actual  : 244000
#
#
# 238
# predict : -76616.17047018802
# actual  : 82375
#
#
# 238
# predict : 20441.621977588686
# actual  : 171000
#
#
# 238
# predict : 44316.777794705646
# actual  : 220000
#
#
# 238
# predict : -32819.065940120374
# actual  : 124000
#
#
# 238
# predict : -23975.501530056237
# actual  : 114000
#
#
# 238
# predict : -9749.299014092656
# actual  : 128900
#
#
# 238
# predict : -15521.766811418813
# actual  : 133500
#
#
# 238
# predict : 17888.408608674363
# actual  : 189000
#
#
# 238
# predict : -20827.867525506124
# actual  : 106000
#
#
# 238
# predict : 109371.57491947239
# actual  : 372500
#
#
# 238
# predict : 37878.17141402402
# actual  : 173000
#
#
# 238
# predict : 15334.208336359763
# actual  : 162500
#
#
# 238
# predict : 39858.353434788645
# actual  : 190000
#
#
# 238
# predict : -2615.678313963872
# actual  : 129000
#
#
# 238
# predict : -7261.756720652338
# actual  : 137500
#
#
# 238
# predict : -10795.29637053376
# actual  : 146000
#
#
# 238
# predict : -10795.29637053376
# actual  : 146000
#
#
# 238
# predict : 22629.921760924044
# actual  : 164500
#
#
# 238
# predict : 14449.365629656182
# actual  : 178000
#
#
# 238
# predict : 73180.74460225692
# actual  : 268500
#
#
# 238
# predict : 107348.29806359211
# actual  : 382500
#
#
# 238
# predict : -22125.937053513073
# actual  : 124000
#
#
# 238
# predict : 21071.955566640012
# actual  : 176000
#
#
# 238
# predict : -22744.25978519494
# actual  : 116000
#
#
# 238
# predict : 63018.5364846703
# actual  : 252000
#
#
# 238
# predict : 51228.3912710275
# actual  : 230000
#
#
# 238
# predict : -10422.91952617676
# actual  : 127500
#
#
# 238
# predict : 3915.6243942984147
# actual  : 150000
#
#
# 238
# predict : 32269.87667234568
# actual  : 184000
#
#
# 238
# predict : -24554.39894780185
# actual  : 105000
#
#
# 238
# predict : 10412.435518403247
# actual  : 143500
#
#
# 238
# predict : -62912.231025970366
# actual  : 73000
#
#
# 238
# predict : -25929.679376087966
# actual  : 130000
#
#
# 238
# predict : 27966.724177290103
# actual  : 176000
#
#
# 238
# predict : 251.77166092733387
# actual  : 145000
#
#
# 238
# predict : 20163.232233581017
# actual  : 175500
#
#
# 238
# predict : 23752.34273515141
# actual  : 168500
#
#
# 238
# predict : 4113.719525267545
# actual  : 140000
#
#
# 238
# predict : 99980.73220145662
# actual  : 374000
#
#
# 238
# predict : 39082.40418051486
# actual  : 184000
#
#
# 238
# predict : 50692.44013394386
# actual  : 209500
#
#
# 238
# predict : -8750.804848209722
# actual  : 136000
#
#
# 238
# predict : -29284.55077022093
# actual  : 138000
#
#
# 238
# predict : 35201.20899404009
# actual  : 189000
#
#
# 238
# predict : 64897.87222872354
# actual  : 293200
#
#
# 238
# predict : 16171.23417630815
# actual  : 180500
#
#
# 238
# predict : 51464.94508424867
# actual  : 214000
#
#
# 238
# predict : 58013.00749101059
# actual  : 237000
