# %%
import pandas as pd 
import numpy as np 
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
import pylab as pl
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("house-prices-advanced-regression-techniques/train.csv")
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows',50)

# %%
df.drop(['Alley',"PoolQC","MiscFeature", "MiscVal", "PoolArea", "Fence", "FireplaceQu", "LotFrontage"], axis=1, inplace=True)

# %%
plt.figure(figsize=(15,8))

sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df = df.dropna()

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 0        1          60       RL     8450   Pave      Reg         Lvl
# 1        2          20       RL     9600   Pave      Reg         Lvl
# 2        3          60       RL    11250   Pave      IR1         Lvl
# 3        4          70       RL     9550   Pave      IR1         Lvl
# 4        5          60       RL    14260   Pave      IR1         Lvl
# ...    ...         ...      ...      ...    ...      ...         ...
# 1455  1456          60       RL     7917   Pave      Reg         Lvl
# 1456  1457          20       RL    13175   Pave      Reg         Lvl
# 1457  1458          70       RL     9042   Pave      Reg         Lvl
# 1458  1459          20       RL     9717   Pave      Reg         Lvl
# 1459  1460          20       RL     9937   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope Neighborhood Condition1 Condition2  \
# ...

# %%
plt.scatter(df["1stFlrSF"], df.iloc[:,-1])

# %%
encoder = LabelEncoder()

# %%
for i in df.columns:
    if df[i].dtype == 'object': 
        encoder.fit_transform(list(df[i].values))
        df[i] = encoder.transform(df[i].values)

# %%
df
# Out:
#         Id  MSSubClass  MSZoning  LotArea  Street  LotShape  LandContour  \
# 0        1          60         3     8450       1         3            3
# 1        2          20         3     9600       1         3            3
# 2        3          60         3    11250       1         0            3
# 3        4          70         3     9550       1         0            3
# 4        5          60         3    14260       1         0            3
# ...    ...         ...       ...      ...     ...       ...          ...
# 1455  1456          60         3     7917       1         3            3
# 1456  1457          20         3    13175       1         3            3
# 1457  1458          70         3     9042       1         3            3
# 1458  1459          20         3     9717       1         3            3
# 1459  1460          20         3     9937       1         3            3
#
#       Utilities  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# ...

# %%
first = df.iloc[:,[i for i in range(5)]+[-1]]

second = df.iloc[:,25:50]

third = df.iloc[:,50:73]

# %%
df.iloc[1]
# Out:
# Id                    2.0
# MSSubClass           20.0
# MSZoning              3.0
# LotArea            9600.0
# Street                1.0
#                    ...
# MoSold                5.0
# YrSold             2007.0
# SaleType              8.0
# SaleCondition         4.0
# SalePrice        181500.0
# Name: 1, Length: 73, dtype: float64

# %%
sns.scatterplot(df.iloc[:,3], df.iloc[:,-1], hue=df["Neighborhood"])
sns.save
# Out:
# /Users/tonypark/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='LotArea', ylabel='SalePrice'>

# %%
df_mean = df.groupby("Neighborhood")

# %%
df_mean
# Out:
#                       Id  MSSubClass       LotArea  OverallQual  OverallCond  \
# Neighborhood
# Blmngtn       773.941176  114.117647   3398.176471     7.176471     5.000000
# Blueste       778.500000  160.000000   1625.000000     6.000000     6.000000
# BrDale        685.800000  160.000000   1809.066667     5.666667     5.466667
# BrkSide       711.851064   54.255319   7689.872340     5.425532     6.361702
# ClearCr       592.000000   52.692308  31898.884615     6.000000     5.730769
# CollgCr       727.691781   43.390411   9608.856164     6.657534     5.246575
# Crawfor       806.500000   59.000000  11392.520000     6.280000     6.660000
# Edwards       794.300000   56.357143  10692.771429     5.328571     5.542857
# Gilbert       754.272727   58.181818  11381.038961     6.584416     5.116883
# IDOTRR        615.586207   45.689655   8426.620690     4.758621     5.517241
# MeadowV       689.333333  158.333333   2593.750000     4.583333     5.166667
# ...

# %%
plt.scatter(df_mean.iloc[:,1], df_mean.iloc[:,-1])

# %%
for i in range(df.shape[1]):
    print(i)
    
    sns.scatterplot(df.iloc[:,i], df.iloc[:,-1], hue=df["Neighborhood"])

    plt.savefig(f"{df.columns[i]} vs price")
    plt.clf()
# Out:
# 0
# /Users/tonypark/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# 1
# /Users/tonypark/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# 2
# ...

# %%
df.columns[1]
# Out:
# 'MSSubClass'

# %%
sample["MSZoning"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/h6/42c9p3812y7d0bfktf9ljfq00000gn/T/ipykernel_90522/2126660751.py in <module>
# ----> 1 sample["MSZoning"].plot()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ...

# %%
x = sample.select_dtypes(include=np.number)

# %%
x =  x.iloc[:,[1,2,3,4,5,6,7,8,-1]]

# %%
x
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1455          60         62.0     7917            6            5       1999
# 1456          20         85.0    13175            6            6       1978
# 1457          70         66.0     9042            7            9       1941
# 1458          20         68.0     9717            5            6       1950
# 1459          20         75.0     9937            5            6       1965
#
#       YearRemodAdd  MasVnrArea  SalePrice
# ...

# %%
plt.figure(figsize=(15,8))

sns.pairplot(x, hue=)

# %%
sns.scatterplot(df["OverallQual"], df["SalePrice"], hue=df["Neighborhood"])
# Out:
# /Users/tonypark/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='OverallQual', ylabel='SalePrice'>
